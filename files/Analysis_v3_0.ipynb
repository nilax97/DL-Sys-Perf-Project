# %%
import warnings
import os
warnings.filterwarnings("ignore")

# %%
def get_model_stored_train_times(dir_path):
  # Necessary Imports
  import os
  import numpy as np
  from collections import defaultdict
  import pickle

  data_dict = defaultdict(list)

  for file_name in os.listdir(dir_path):
    file_path = os.path.join(dir_path, file_name)
    file_name_elems = file_name.split('-')
    varying_attr_name = file_name_elems[1]
    varying_attr_val = int(file_name_elems[2][:file_name_elems[2].find('.')])

    # Forming a list of tuples for each of the varying attributes...
    if varying_attr_name not in data_dict.keys():
      data_dict[varying_attr_name] = []

    if os.path.isfile(file_path):
      file_to_read = open(file_path, "rb")
      data = pickle.load(file_to_read)
      data_dict[varying_attr_name].append((varying_attr_val, np.mean(data['train_times'])))

  # Sorting the list of tuples to get cleaner analysis
  for varying_attr_name, varying_attr_vals in data_dict.items():
    data_dict[varying_attr_name] = sorted(varying_attr_vals, key = lambda x : x[0])

  return data_dict

# %%
# VGG
dir_path = os.path.join("DL_Project_CS_NA", "vgg")
vgg_data_dict = get_model_stored_train_times(dir_path)
print(vgg_data_dict)
# Out:
# defaultdict(<class 'list'>, {'hidden_layers_size': [(1, 0.3881954286247492), (2, 0.39754979780409483), (3, 0.405678666010499), (4, 0.4139540744014084), (5, 0.4186350601958111), (6, 0.42472191718406976), (7, 0.4311083490261808), (8, 0.44571544195059687), (9, 0.45491067178081723), (10, 0.45982287558726964)], 'batch_size': [(8, 0.38726100279018283), (16, 0.23682410700712353), (32, 0.21249667941592634), (64, 0.1929894849890843), (128, 0.18920662621967493), (256, 0.1949071229668334), (512, 0.21088456357829272), (1024, 0.24219194781035186)], 'input_size': [(1024, 0.39068768981378527), (2048, 0.7816217797808349), (4096, 1.56872666280251), (8192, 3.104372058366425), (16384, 6.222492517647334), (32768, 12.452346738171764), (65536, 24.745914796204307), (131072, 49.58699352359399), (262144, 98.55480755779426), (524288, 197.65596985279117)], 'hidden_layers': [(100, 0.38797559740487486), (316, 0.39287562100216744), (1000, 0.5226884454255923), (3162, 1.033326030196622)], 'output_shape': [(2, 0.38650226020254197), (4, 0.38963335403241217), (8, 0.3876576295820996), (16, 0.38390201879665253), (32, 0.3842873853864148), (64, 0.38768849160987884), (128, 0.3904545129975304), (256, 0.3896728675812483), (512, 0.39234055259730666), (1024, 0.3986308439867571)], 'vgg_layers_size': [(1, 0.38770033658947795), (2, 0.485713077429682), (3, 0.581900633778423), (4, 0.6901274844072759), (5, 0.7967059904010967), (6, 0.9013576693832874), (7, 1.1407210969831794)], 'input_shape': [(128, 0.3933127799769863), (192, 0.607300894614309), (256, 1.035584019590169), (320, 1.552770115621388), (384, 2.1705227565718817), (448, 2.9181442577857526), (512, 3.789317086385563), (576, 4.774879668606445), (640, 5.908138345368206), (704, 7.114792368025519), (768, 8.456228210008703), (832, 9.90819305081386), (896, 11.488219144381583), (960, 13.157007807400078), (1024, 14.986894323583693)], 'vgg_layers': [(2, 0.38910148120485244), (3, 0.452203903417103), (4, 0.5092771352035925), (5, 0.580823664390482), (6, 0.6641136470250786), (7, 0.7553538646083325), (8, 0.8339825171977282), (9, 0.9207808220293373), (10, 1.0052432535914704)], 'filters': [(16, 0.38942907040473074), (32, 0.42679476181510834), (64, 0.5780598077690229), (128, 0.9329997079912573), (256, 1.984057900775224), (512, 6.007506785192527), (1024, 18.8343904793961)]})

089381), (4, 0.47470497163012626), (5, 0.5548974068369716), (6, 0.6349498764611781), (7, 0.7246519405860454), (8, 0.8250891496427357), (9, 0.8797394540160894), (10, 0.9579497360158712)], 'output_shape': [(2, 0.22543085198849439), (4, 0.23179585905745625), (8, 0.2326792746782303), (16, 0.2250751113984734), (32, 0.23500818675383925), (64, 0.24075919277966024), (128, 0.2412922764196992), (256, 0.22627729121595622), (512, 0.254838742595166), (1024, 0.26502262209542093)], 'input_size': [(1024, 0.2416366450022906), (2048, 0.4663548045326024), (4096, 0.9393883964046836), (8192, 1.888547660363838), (16384, 3.7548155091702937), (32768, 7.429035638552159), (65536, 14.71551221641712), (131072, 29.472164526907726), (262144, 58.42130735740066), (524288, 116.77254537963309)]})

# %%
# Visualize all the data for the training times
def plot_varying_attrs_vs_train_times(model_name, dict_data):
  import matplotlib.pyplot as plt
  import seaborn as sns

  plt.rcParams["figure.figsize"] = (15,40)
  num_plots = len(dict_data)
  fig, axs = plt.subplots(num_plots)
  fig.suptitle(f'Training Times (y-axis) for Models (with varying attributes): {model_name.upper()}')

  plt_counter = 0
  for varying_attr_name, varying_attr_vals in dict_data.items():
    x_vals = [attr_val_1 for attr_val_1, attr_val_2 in varying_attr_vals]
    y_vals = [attr_val_2 for attr_val_1, attr_val_2 in varying_attr_vals]
    axs[plt_counter].set_title(varying_attr_name)
    sns.barplot(x_vals, y_vals, ax = axs[plt_counter])
    plt_counter += 1
  
  # Saving the image
  plt.savefig(os.path.join("DL_Project_CS_NA", "Visualizations", f'{model_name}_data_vs.png'))

# %%
# VGG Visualizations
plot_varying_attrs_vs_train_times('VGG', vgg_data_dict)

# %%
# ResNet Visualizations
plot_varying_attrs_vs_train_times('ResNet', resnet_data_dict)

# %%
# Inception Visualizations
plot_varying_attrs_vs_train_times('Inception', inception_data_dict)

# %%
# fc Visualizations
plot_varying_attrs_vs_train_times('Fully Connected', fc_data_dict)

# %%
def get_model_train_times_per_aux_vars(dir_path):
  # Necessary Imports
  import os
  import numpy as np
  from collections import defaultdict
  import pickle

  data_dict = defaultdict(dict)

  for file_name in os.listdir(dir_path):
    if file_name.find("input_shape") == -1 and file_name.find("layers") == -1:
      continue
    file_path = os.path.join(dir_path, file_name)
    file_name_elems = file_name.split('-')
    varying_attr_name = file_name_elems[1]

    # Forming a dict of list of tuples for each of the varying attributes...
    if varying_attr_name not in data_dict.keys():
      data_dict[varying_attr_name] = dict()

    if os.path.isfile(file_path):
      file_to_read = open(file_path, "rb")
      data = pickle.load(file_to_read)

      total_flops = sum(list(data['flops_param'].values()))
      if 'flops_param' not in data_dict[varying_attr_name].keys():
        data_dict[varying_attr_name]['flops_param'] = []
      data_dict[varying_attr_name]['flops_param'].append((total_flops, np.mean(data['train_times'])))

      trainable_params = data['weights_param']['trainable']
      if 'trainable' not in data_dict[varying_attr_name].keys():
        data_dict[varying_attr_name]['trainable'] = []
      data_dict[varying_attr_name]['trainable'].append((trainable_params, np.mean(data['train_times'])))

      total_depth = sum(list(data['layers_param'].values()))
      if 'layers_param' not in data_dict[varying_attr_name].keys():
        data_dict[varying_attr_name]['layers_param'] = []
      data_dict[varying_attr_name]['layers_param'].append((total_depth, np.mean(data['train_times'])))

  # Sorting the list of tuples to get cleaner analysis
  for varying_attr_name, varying_attr_vals in data_dict.items():
    for varying_attr_val_name, varying_data in varying_attr_vals.items():
      data_dict[varying_attr_name][varying_attr_val_name] = sorted(varying_data, key = lambda x : x[0])

  return data_dict

# %%
# VGG
dir_path = os.path.join("DL_Project_CS_NA", "vgg")
vgg_data_dict_2 = get_model_train_times_per_aux_vars(dir_path)
print(vgg_data_dict_2)
# Out:
# defaultdict(<class 'dict'>, {'hidden_layers_size': {'flops_param': [(118490244, 0.3881954286247492), (118530544, 0.39754979780409483), (118570844, 0.405678666010499), (118611144, 0.4139540744014084), (118651444, 0.4186350601958111), (118691744, 0.42472191718406976), (118732044, 0.4311083490261808), (118772344, 0.44571544195059687), (118812644, 0.45491067178081723), (118852944, 0.45982287558726964)], 'trainable': [(6556734, 0.3881954286247492), (6566834, 0.39754979780409483), (6576934, 0.405678666010499), (6587034, 0.4139540744014084), (6597134, 0.4186350601958111), (6607234, 0.42472191718406976), (6617334, 0.4311083490261808), (6627434, 0.44571544195059687), (6637534, 0.45491067178081723), (6647634, 0.45982287558726964)], 'layers_param': [(9, 0.3881954286247492), (10, 0.39754979780409483), (11, 0.405678666010499), (12, 0.4139540744014084), (13, 0.4186350601958111), (14, 0.42472191718406976), (15, 0.4311083490261808), (16, 0.44571544195059687), (17, 0.45491067178081723), (18, 0.45982287558726964)]}, 'hidden_layers': {'flops_param': [(118490244, 0.38797559740487486), (175115724, 0.39287562100216744), (313006992, 0.5226884454255923), (596399790, 1.033326030196622)], 'trainable': [(6556734, 0.38797559740487486), (20713158, 0.39287562100216744), (65541834, 0.5226884454255923), (207237152, 1.033326030196622)], 'layers_param': [(9, 0.38797559740487486), (9, 0.39287562100216744), (9, 1.033326030196622), (9, 0.5226884454255923)]}, 'vgg_layers_size': {'flops_param': [(118490244, 0.38770033658947795), (219939972, 0.485713077429682), (327287940, 0.581900633778423), (437585028, 0.6901274844072759), (549160366, 0.7967059904010967), (661137214, 0.9013576693832874), (773592894, 1.1407210969831794)], 'trainable': [(1113982, 0.6901274844072759), (1590654, 0.7967059904010967), (1711230, 0.581900633778423), (3293950, 0.485713077429682), (4927870, 0.9013576693832874), (6556734, 0.38770033658947795), (18987390, 1.1407210969831794)], 'layers_param': [(9, 0.38770033658947795), (14, 0.485713077429682), (19, 0.581900633778423), (24, 0.6901274844072759), (29, 0.7967059904010967), (34, 0.9013576693832874), (39, 1.1407210969831794)]}, 'input_shape': {'flops_param': [(118490244, 0.3933127799769863), (266601604, 0.607300894614309), (473957508, 1.035584019590169), (740557956, 1.552770115621388), (1066402948, 2.1705227565718817), (1451492484, 2.9181442577857526), (1895826564, 3.789317086385563), (2399405188, 4.774879668606445), (2962228356, 5.908138345368206), (3584296068, 7.114792368025519), (4265608324, 8.456228210008
), (965002, 0.23758634594269096), (1029002, 0.24646271276287735)], 'layers_param': [(6, 0.2510732346680015), (6, 0.23550037401728333), (6, 0.23758634594269096), (6, 0.24646271276287735), (6, 0.2500524267554283), (6, 0.2504738200921565), (6, 0.23969847061671318), (6, 0.24631014154292644), (6, 0.23964097439311444), (6, 0.24155985624529422), (6, 0.24853883720934392), (6, 0.2479319719132036), (6, 0.23624695958569647), (6, 0.2459648641757667), (6, 0.23885767739266156)]}, 'hidden_layers': {'flops_param': [(281068, 0.2279650179669261), (2302068, 0.3070636219345033), (4323068, 0.3897342340089381), (6344068, 0.47470497163012626), (8365068, 0.5548974068369716), (10386068, 0.6349498764611781), (12407068, 0.7246519405860454), (14428068, 0.8250891496427357), (16449068, 0.8797394540160894), (18470068, 0.9579497360158712)], 'trainable': [(133002, 0.2279650179669261), (1136002, 0.3070636219345033), (2139002, 0.3897342340089381), (3142002, 0.47470497163012626), (4145002, 0.5548974068369716), (5148002, 0.6349498764611781), (6151002, 0.7246519405860454), (7154002, 0.8250891496427357), (8157002, 0.8797394540160894), (9160002, 0.9579497360158712)], 'layers_param': [(6, 0.2279650179669261), (9, 0.3070636219345033), (12, 0.3897342340089381), (15, 0.47470497163012626), (18, 0.5548974068369716), (21, 0.6349498764611781), (24, 0.7246519405860454), (27, 0.8250891496427357), (30, 0.8797394540160894), (33, 0.9579497360158712)]}})

# %%
aux_vars = ['flops_param', 'trainable', 'layers_param']

# %%
# Visualize all the data for the training times
def plot_varying_aux_attrs_vs_train_times(model_name, dict_data):
  import matplotlib.pyplot as plt
  import seaborn as sns

  plt.rcParams["figure.figsize"] = (15,80)
  num_plots = len(aux_vars) * len(dict_data)
  fig, axs = plt.subplots(num_plots)
  fig.suptitle(f'Training Times (y-axis) for Models (with varied attributes): {model_name.upper()}')

  plt_counter = 0
  for varying_attr_name, varying_attr_vals in dict_data.items():
    for varying_attr_val_name, varying_attr_data in varying_attr_vals.items():
      x_vals = [attr_val_1 for attr_val_1, attr_val_2 in varying_attr_data]
      y_vals = [attr_val_2 for attr_val_1, attr_val_2 in varying_attr_data]
      axs[plt_counter].set_title(f"{varying_attr_val_name} w.r.t {varying_attr_name}")
      sns.lineplot(x_vals, y_vals, ax = axs[plt_counter])
      plt_counter += 1
  
  # Saving the image
  plt.savefig(os.path.join("DL_Project_CS_NA", "Visualizations", f'{model_name}_aux_vars_data_vs.png'))

# %%
# VGG Aux Variable Visualizations
plot_varying_aux_attrs_vs_train_times('VGG', vgg_data_dict_2)

# %%
# ResNet Aux Variable Visualizations
plot_varying_aux_attrs_vs_train_times('ResNet', resnet_data_dict_2)

# %%
# Inception Aux Variable Visualizations
plot_varying_aux_attrs_vs_train_times('Inception', inception_data_dict_2)

# %%
# fc Aux Variable Visualizations
plot_varying_aux_attrs_vs_train_times('Fully Connected', fc_data_dict_2)

# %%
'''

All the Visualizations are shown above. Using this analysis, 
now we will form a regression model to calculate the training time 
based on the following inputs (above mentioned) from the user.

'''
# Out:
# '\nAll the Visualizations are shown above. Using this analysis, \nnow we will form a regression model to calculate the training time \nbased on the following inputs (above mentioned) from the user.\n'
